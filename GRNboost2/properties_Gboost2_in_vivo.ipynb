# %%
import numpy as np
import matplotlib.pyplot as plt
import scanpy as sc
import pandas as pd
import time
import networkx as nx
import anndata as An
import infomap as Im

# %%
G65=nx.read_gexf("Construction/GRNboot_6.5.gexf")
G75=nx.read_gexf("Construction/GRNboot_7.5.gexf")
G85=nx.read_gexf("Construction/GRNboot_8.5.gexf")
G95=nx.read_gexf("Construction/GRNboot_9.5.gexf")

# %%
fig,ax=plt.subplots(2,2,figsize=(10,10))
a=ax[0,0].hist(np.array(G65.in_degree())[:,1].astype(int),log=True,range=[-0.1,2000],label="Day: 6.5 ",color="blue",bins=20)
b=ax[0,1].hist(np.array(G75.in_degree())[:,1].astype(int),log=True,range=[-0.1,2000],label="Day: 7.5 ",color="red",bins=20)
c=ax[1,0].hist(np.array(G85.in_degree())[:,1].astype(int),log=True,range=[-0.1,2000],label="Day: 8.5 ",color="green",bins=20)
d=ax[1,1].hist(np.array(G95.in_degree())[:,1].astype(int),log=True,range=[-0.1,2000],label="Day: 9.5 ",color="m",bins=20)
ax[0,0].set_xlabel("Degree_in",fontsize=14)
ax[0,0].set_ylabel("Count",fontsize=14)
ax[0,1].set_xlabel("Degree_in",fontsize=14)
ax[0,1].set_ylabel("Count",fontsize=14)
ax[1,0].set_xlabel("Degree_in",fontsize=14)
ax[1,0].set_ylabel("Count",fontsize=14)
ax[1,1].set_xlabel("Degree_in",fontsize=14)
ax[1,1].set_ylabel("Count",fontsize=14)
ax[0,1].legend(fontsize=12)
ax[1,0].legend(fontsize=12)
ax[1,1].legend(fontsize=12)
ax[0,0].legend(fontsize=12)

fig.savefig("Degree_in_GRNboot_in_Vivo.png")

# %%
fig,ax=plt.subplots(2,2,figsize=(10,10))
au=ax[0,0].hist(np.array(G65.out_degree())[:,1].astype(int),log=True,range=[-0.1,1250],label="Day: 6.5 ",color="blue",bins=20)
bu=ax[0,1].hist(np.array(G75.out_degree())[:,1].astype(int),log=True,range=[-0.1,1250],label="Day: 7.5 ",color="red",bins=20)
cu=ax[1,0].hist(np.array(G85.out_degree())[:,1].astype(int),log=True,range=[-0.1,1250],label="Day: 8.5 ",color="green",bins=20)
du=ax[1,1].hist(np.array(G95.out_degree())[:,1].astype(int),log=True,range=[-0.1,1250],label="Day: 9.5 ",color="m",bins=20)
ax[0,0].set_xlabel("Degree_out",fontsize=14)
ax[0,0].set_ylabel("Count",fontsize=14)
ax[0,1].set_xlabel("Degree_out",fontsize=14)
ax[0,1].set_ylabel("Count",fontsize=14)
ax[1,0].set_xlabel("Degree_out",fontsize=14)
ax[1,0].set_ylabel("Count",fontsize=14)
ax[1,1].set_xlabel("Degree_out",fontsize=14)
ax[1,1].set_ylabel("Count",fontsize=14)
ax[0,1].legend(fontsize=12)
ax[1,0].legend(fontsize=12)
ax[1,1].legend(fontsize=12)
ax[0,0].legend(fontsize=12)
fig.savefig("Degree_out_GRNboot_in_Vivo.png")

# %%
fig,ax=plt.subplots(2,2,figsize=(10,10))
ax[0,0].plot(np.array(G65.out_degree())[:,1].astype(float),np.array(G65.in_degree())[:,1].astype(float),'.b',label="Day: 6.5 ")
ax[0,1].plot(np.array(G75.out_degree())[:,1].astype(float),np.array(G75.in_degree())[:,1].astype(float),'.r',label="Day: 7.5 ")
ax[1,0].plot(np.array(G85.out_degree())[:,1].astype(float),np.array(G85.in_degree())[:,1].astype(float),'.g',label="Day: 8.5 ")
ax[1,1].plot(np.array(G95.out_degree())[:,1].astype(float),np.array(G95.in_degree())[:,1].astype(float),'.m',label="Day: 9.5 ")
ax[0,0].set_xlabel("Degree_out",fontsize=14)
ax[0,0].set_ylabel("Count",fontsize=14)
ax[0,1].set_xlabel("Degree_out",fontsize=14)
ax[0,1].set_ylabel("Count",fontsize=14)
ax[1,0].set_xlabel("Degree_out",fontsize=14)
ax[1,0].set_ylabel("Count",fontsize=14)
ax[1,1].set_xlabel("Degree_out",fontsize=14)
ax[1,1].set_ylabel("Count",fontsize=14)
ax[0,0].set_xlim(0,1200)
ax[0,0].set_ylim(0,2000)
ax[0,1].set_xlim(0,1200)
ax[0,1].set_ylim(0,2000)
ax[1,0].set_xlim(0,1200)
ax[1,0].set_ylim(0,2000)
ax[1,1].set_xlim(0,1200)
ax[1,1].set_ylim(0,2000)
ax[0,1].legend(fontsize=12)
ax[1,0].legend(fontsize=12)
ax[1,1].legend(fontsize=12)
ax[0,0].legend(fontsize=12)
fig.savefig("Degree_in_degree_out_GRNboot_in_Vivo.png")

# %%
fig,ax=plt.subplots(2,2,figsize=(10,10))
ax[0,0].plot(np.log10(a[1][1:]),np.log10(a[0]),'.b',label="Day: 6.5 ")
ax[0,1].plot(np.log10(b[1][1:]),np.log10(b[0]),'.r',label="Day: 7.5 ")
ax[1,0].plot(np.log10(c[1][1:]),np.log10(c[0]),'.g',label="Day: 8.5 ")
ax[1,1].plot(np.log10(d[1][1:]),np.log10(d[0]),'.m',label="Day: 9.5 ")
ax[0,0].set_xlabel("log(Degree_in)",fontsize=14)
ax[0,0].set_ylabel("log(Count)",fontsize=14)
ax[0,1].set_xlabel("log(Degree_in)",fontsize=14)
ax[0,1].set_ylabel("log(Count)",fontsize=14)
ax[1,0].set_xlabel("log(Degree_in)",fontsize=14)
ax[1,0].set_ylabel("log(Count)",fontsize=14)
ax[1,1].set_xlabel("log(Degree_in)",fontsize=14)
ax[1,1].set_ylabel("log(Count)",fontsize=14)
ax[0,1].legend(fontsize=12)
ax[1,0].legend(fontsize=12)
ax[1,1].legend(fontsize=12)
ax[0,0].legend(fontsize=12)
fig.savefig("in_log_count_log_GRNboot_in_Vivo.png")
# Out:
# <ipython-input-8-9ed1129656c0>:2: RuntimeWarning: divide by zero encountered in log10
#   ax[0,0].plot(np.log10(a[1][1:]),np.log10(a[0]),'.b',label="Day: 6.5 ")
# <ipython-input-8-9ed1129656c0>:3: RuntimeWarning: divide by zero encountered in log10
#   ax[0,1].plot(np.log10(b[1][1:]),np.log10(b[0]),'.r',label="Day: 7.5 ")
# <ipython-input-8-9ed1129656c0>:4: RuntimeWarning: divide by zero encountered in log10
#   ax[1,0].plot(np.log10(c[1][1:]),np.log10(c[0]),'.g',label="Day: 8.5 ")
# <ipython-input-8-9ed1129656c0>:5: RuntimeWarning: divide by zero encountered in log10
#   ax[1,1].plot(np.log10(d[1][1:]),np.log10(d[0]),'.m',label="Day: 9.5 ")

# %%
fig,ax=plt.subplots(2,2,figsize=(10,10))
ax[0,0].plot(np.log10(au[1][1:]),np.log10(au[0]),'.b',label="Day: 6.5 ")
ax[0,1].plot(np.log10(bu[1][1:]),np.log10(bu[0]),'.r',label="Day: 7.5 ")
ax[1,0].plot(np.log10(cu[1][1:]),np.log10(cu[0]),'.g',label="Day: 8.5 ")
ax[1,1].plot(np.log10(du[1][1:]),np.log10(du[0]),'.m',label="Day: 9.5 ")
ax[0,0].set_xlabel("log(Degree_out)",fontsize=14)
ax[0,0].set_ylabel("log(Count)",fontsize=14)
ax[0,1].set_xlabel("log(Degree_out)",fontsize=14)
ax[0,1].set_ylabel("log(Count)",fontsize=14)
ax[1,0].set_xlabel("log(Degree_out)",fontsize=14)
ax[1,0].set_ylabel("log(Count)",fontsize=14)
ax[1,1].set_xlabel("log(Degree_out)",fontsize=14)
ax[1,1].set_ylabel("log(Count)",fontsize=14)
ax[0,1].legend(fontsize=12)
ax[1,0].legend(fontsize=12)
ax[1,1].legend(fontsize=12)
ax[0,0].legend(fontsize=12)
fig.savefig("out_log_count_log_GRNboot_in_Vivo.png")
# Out:
# <ipython-input-9-2462c200569f>:3: RuntimeWarning: divide by zero encountered in log10
#   ax[0,1].plot(np.log10(bu[1][1:]),np.log10(bu[0]),'.r',label="Day: 7.5 ")
# <ipython-input-9-2462c200569f>:4: RuntimeWarning: divide by zero encountered in log10
#   ax[1,0].plot(np.log10(cu[1][1:]),np.log10(cu[0]),'.g',label="Day: 8.5 ")
# <ipython-input-9-2462c200569f>:5: RuntimeWarning: divide by zero encountered in log10
#   ax[1,1].plot(np.log10(du[1][1:]),np.log10(du[0]),'.m',label="Day: 9.5 ")

# %%
im3 =Im.Infomap("--clu --ftree -d -N 5 -2")
im3.read_file("Construction/GRNboot_6.5.net")
im3.run()
im4 =Im.Infomap("--clu --ftree -d -N 5 -2")
im4.read_file("Construction/GRNboot_7.5.net")
im4.run()
im5 =Im.Infomap("--clu --ftree -d -N 5 -2")
im5.read_file("Construction/GRNboot_8.5.net")
im5.run()
im6 =Im.Infomap("--clu --ftree -d -N 5 -2")
im6.read_file("Construction/GRNboot_9.5.net")
im6.run()

# %%
fig,ax=plt.subplots(2,2,figsize=(10,10))
a3=ax[0,0].hist(im3.get_dataframe(columns=["flow"]).flow,log=True,color="blue",bins=20,range=[-0.00001,0.0009],label="Day: 6.5 ")
b3=ax[0,1].hist(im4.get_dataframe(columns=["flow"]).flow,log=True,color="red",bins=20,range=[-0.00001,0.0009],label="Day: 7.5 ")
c3=ax[1,0].hist(im5.get_dataframe(columns=["flow"]).flow,log=True,color="green",bins=20,range=[-0.00001,0.0009],label="Day: 8.5 ")
d3=ax[1,1].hist(im6.get_dataframe(columns=["flow"]).flow,log=True,color="m",bins=20,range=[-0.00001,0.0009],label="Day: 9.5 ")
ax[0,0].legend(fontsize=12)
ax[0,1].legend(fontsize=12)
ax[1,1].legend(fontsize=12)
ax[1,0].legend(fontsize=12)
ax[0,0].set_xlabel("Flow",fontsize=14)
ax[0,1].set_xlabel("Flow",fontsize=14)
ax[1,1].set_xlabel("Flow",fontsize=14)
ax[1,0].set_xlabel("Flow",fontsize=14)
ax[0,0].set_ylabel("Log(N)",fontsize=14)
ax[0,1].set_ylabel("Log(N)",fontsize=14)
ax[1,1].set_ylabel("Log(N)",fontsize=14)
ax[1,0].set_ylabel("Log(N)",fontsize=14)
ax[0,0].ticklabel_format(axis="x", style="sci", scilimits=(0,0))
ax[0,1].ticklabel_format(axis="x", style="sci", scilimits=(0,0))
ax[1,0].ticklabel_format(axis="x", style="sci", scilimits=(0,0))
ax[1,1].ticklabel_format(axis="x", style="sci", scilimits=(0,0))
fig.savefig("flow_dist_0_in_Vivo.png")

# %%
bet65=np.load("Bet_GRN_6.5.npy")
bet75=np.load("Bet_GRN_7.5.npy")
bet85=np.load("Bet_GRN_8.5.npy")
bet95=np.load("Bet_GRN_9.5.npy")

# %%
bet65[1,:].astype(float)
# Out:
# array([4.64942763e-04, 6.35661353e-04, 1.11018396e-03, ...,
#        2.08364499e-05, 1.94026656e-05, 1.72417821e-05])

# %%
fig,ax=plt.subplots(2,2,figsize=(10,10))
a3=ax[0,0].hist(bet65[1,:].astype(float),log=True,color="blue",bins=20,label="Day: 6.5 ",range=[-0.0001,0.0035])
b3=ax[0,1].hist(bet75[1,:].astype(float),log=True,color="red",bins=20,label="Day: 7.5 ",range=[-0.0001,0.0035])
c3=ax[1,0].hist(bet85[1,:].astype(float),log=True,color="green",bins=20,label="Day: 8.5 ",range=[-0.0001,0.0035])
d3=ax[1,1].hist(bet95[1,:].astype(float),log=True,color="m",bins=20,label="Day: 9.5 ",range=[-0.0001,0.0035])
ax[0,0].legend(fontsize=14)
ax[0,1].legend(fontsize=14)
ax[1,1].legend(fontsize=14)
ax[1,0].legend(fontsize=14)
ax[0,0].set_xlabel("Betweeness",fontsize=16)
ax[0,1].set_xlabel("Betweeness",fontsize=16)
ax[1,1].set_xlabel("Betweeness",fontsize=16)
ax[1,0].set_xlabel("Betweeness",fontsize=16)
ax[0,0].set_ylabel("Log(N)",fontsize=16)
ax[0,1].set_ylabel("Log(N)",fontsize=16)
ax[1,1].set_ylabel("Log(N)",fontsize=16)
ax[1,0].set_ylabel("Log(N)",fontsize=16)
ax[0,0].ticklabel_format(axis="x", style="sci", scilimits=(0,0))
ax[0,1].ticklabel_format(axis="x", style="sci", scilimits=(0,0))
ax[1,0].ticklabel_format(axis="x", style="sci", scilimits=(0,0))
ax[1,1].ticklabel_format(axis="x", style="sci", scilimits=(0,0))
fig.savefig("Bet_GRN_in_Vivo.png")
